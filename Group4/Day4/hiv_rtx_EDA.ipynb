# %%
#Import packages
import pandas as pd

#Read in data
df = pd.read_csv("~/Desktop/Eneza/eneza_project/HIV-drug-resistance-prediction-from-viral-sequences/Group4/Day1/geno-pheno.dataset.tsv", sep = "\t")

df.head()
# Out:
# /tmp/ipykernel_15876/3782944859.py:5: DtypeWarning: Columns (0: AZT, 1: DDCFoldMatch, 2: TAFFoldMatch) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("~/Desktop/Eneza/eneza_project/HIV-drug-resistance-prediction-from-viral-sequences/Group4/Day1/geno-pheno.dataset.tsv", sep = "\t")
#    RefID  IsolateID IsolateName Species      Type    PtID      Method    3TC  \
# 0    756       9918      CA9918    HIV1  Clinical  1391.0  PhenoSense  200.0
# 1    756       3832      CA3832    HIV1  Clinical  1433.0  PhenoSense  200.0
# 2    756      10464     CA10464    HIV1  Clinical   634.0  PhenoSense  200.0
# 3    756       9928      CA9928    HIV1  Clinical   637.0  PhenoSense  200.0
# 4    756       4372      CA4372    HIV1  Clinical  1274.0  PhenoSense  200.0
#
#   3TCFoldMatch   ABC  ... P291 P292 P293  P294 P295  P296 P297  P298 P299  \
# 0            >   4.6  ...    -    -    -     -    -     -    -     -    -
# ...
